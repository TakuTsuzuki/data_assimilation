# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt #2d plot

# %% [markdown]
# # Task1

# %% [markdown]
# ## Define functions

# %% [markdown]
# ### Define Lorenz96 model

# %%
def Lorenz(X, F):
    dXdt = np.array([])
    for i in xrange(len(X)):
        # assume Periodic boundary condition
        diff = (-X[i-2]*X[i-1]+X[i-1]*X[(i+1)%len(X)]-X[i]+F)
        dXdt = np.append(dXdt, diff)
    dXdt = dXdt.reshape((len(dXdt),1))
    return dXdt

# %% [markdown]
# ### Define runge_kutta solver

# %%
def runge_kutta(X,dt, model=None):
    k1 = dt*Lorenz(X, F)
    k2 = dt*Lorenz(X+k1/2, F)
    k3 = dt*Lorenz(X+k2/2, F)
    k4 = dt*Lorenz(X+k3, F)
    return X + (k1/6 + k2/3 + k3/3 + k4/6)

# %% [markdown]
# ### Define simulator

# %%
def run_simulation(X0, step, dt, model=None):
    trajectory = np.array(X0)
    X =  np.array(X0)
    for t in xrange(step):
        X = runge_kutta(X, dt)
        trajectory = np.concatenate((trajectory, X),axis=1)     
    return trajectory

# %% [markdown]
# ## Run simulator

# %%
#define setting
dt = 0.005
step = 5000

#define parameters
F = 8.000
d=40

#define initial state (white noise) 
X0 = np.random.rand(d, 1)

# Run simulation
data = run_simulation(X0, step, dt)

# %% [markdown]
# ## Visualize results

# %%
plt.plot(data[0,:])

# %% [markdown]
# # Task2

# %% [markdown]
# ## 誤差の平均発達率を調べる(F=8)

# %% [markdown]
# x0乱数なのは良くない．解の空間に落とさないといけない→十分に長い時間シミュレーションするとモデルの解の空間に落ちるので，そこからランダムにサンプリングする．

# %% [markdown]
# ### 解空間上の軌跡を読み込む

# %%
trajectory = np.load('data_raw.npy')

# %% [markdown]
# ### エラーの時間変化を取る

# %%
sample = 100
steps = 2000

errors = np.array([])
for n in xrange(sample):
    #define initial state
    X0 = np.random.rand(d, 1)
    X1 = X0 + 1e-7*np.random.rand(d, 1)

    # Run simulation
    data0 = run_simulation(X0, steps, dt)
    data1 = run_simulation(X1, steps, dt)
    error  = np.sqrt(np.sum(np.power(data0-data1, 2),axis=0))
    errors = np.append(errors, error)

errors = errors.reshape(sample, data0.shape[1])

# %%
np.save('errors.npy', errors)

# %% [markdown]
# ## 10000step分plot

# %%
plt.plot(errors[0])

# %% [markdown]
# ## 2000step × 100 sample走らせて，リアプノフ指数を求めた

# %%
logE = np.log2(np.mean(errors,axis=0))
Var = np.var(errors,axis=0)

# %% [markdown]
# ### y=ax+bをlog2(Mean)に線形回帰し，傾きを求めた

# %%
x=np.array(range(len(logE)))
A = np.array([x,np.ones(len(x))])
A = A.T
a,b = np.linalg.lstsq(A,logE)[0]
print "a: ", a
print "b: ", b
# Out:
# a:  0.0134450167256
# b:  -21.4107600082

# %% [markdown]
# ### log2(Mean)とy=0.013x-21 をプロットした

# %%
plt.plot(x,logE)
plt.plot(x,(a*x+b))
plt.grid()
plt.show()

# %% [markdown]
# ## 自然界のEDT=2dayとして，シミュレーションの時間スケールを推定

# %%
print "dt:  ", dt
print "steps/day (truth)        :  ", 0.4/dt
print "steps/day (estimated):  ", round(1/a,1)
# Out:
# dt:   0.005
# steps/day (truth)        :   80.0
# steps/day (estimated):   74.4

# %% [markdown]
# # Task3

# %% [markdown]
# ## 2 年分積分し、後半 1 年分を 6 時間毎に保存

# %% [markdown]
# ### Run simulator

# %%
#define setting
dt = 0.005
step = 365*4*2*10

#define parameters
F = 8.000
d=40

#define initial state (white noise) 
X0 = np.random.rand(d, 1)

# Run simulation
data = run_simulation(X0, step, dt)

# %%
data_c = data[:,data.shape[1]/2:]
np.save('data_raw.npy', data_c)

# %% [markdown]
# ### 6時間ごとにサンプル

# %%
data_sampled = data_c[:,::10]
np.save('data_sampled.npy', data_sampled)

# %% [markdown]
# # Task4

# %% [markdown]
# ## 3のデータに分散1のノイズを加える

# %%
data=np.load('data_sampled.npy')

# %%
noise = np.random.rand(data.shape[0],data.shape[1])-0.5
data_obs = data+noise
np.save('data_obs.npy', data_obs)

plt.plot(data_obs[0])
plt.plot(data[0])

# %% [markdown]
# # Task5:Kalman filterの実装

# %% [markdown]
# ## Kalman filter の定義

# %% [markdown]
# ### Predict

# %%
def predict(Xa, Pa, C, model= None, delta=1e-7):
    Xf = run_simulation(Xa, step=1, dt=dt, model=None)
    
    # caluculate Targent Linear model
    M = np.array([])
    for i in xrange(len(Xa)):
        e = delta*(np.zeros(len(Xa))[i]==1)
        x = Xa+e
    
    Pf = np.dot(M,np.dot(Pa,M.T))
    return Xf, Pf, error

# %% [markdown]
# ### Fitting

# %%
def fit(Xf, Pf, H, R):
    
    return Xa, Pa, error

# %% [markdown]
# ### Assimilation

# %%
def Kalman_filter(data, X0, P0, C, H, R ,dt, model=None):
    #Logging
    records={}
    records["Xf"]=np.array([])
    records["Xa"]=np.array([])
    records["Pf"]=np.array([])
    records["Pa"]=np.array([])
    records["E_pred"]=np.array([])
    records["E_fit"]=np.array([])
    
    # assimilation
    for t in xrange(obs.shape[1]):
        Xf, Pf, E_pred = predict(Xa, Pa, C)
        Xa, Pa, E_fit = fit(Xf, Pf, H, R)
    
        records["Xf"]=records["Xf"].append(Xf)
        records["Xa"]=records["Xa"].append(Xa)
        records["Pf"]=records["Pf"].append(Pf)
        records["Pa"]=records["Pa"].append(Pa)
        records["E_pred"]=records["E_pred"].append(E_pred)
        records["E_fit"]=records["E_fit"].append(E_fit)
    
    records["Xf"]=records["Xf"].reshape((obs.shape[0],obs.shape[1]))
    records["Xa"]=records["Xa"].reshape((obs.shape[0],obs.shape[1]))
    records["Pf"]=records["Pf"].reshape((obs.shape[1],obs.shape[0],obs.shape[0]))
    records["Pa"]=records["Pa"].reshape((obs.shape[1],obs.shape[0],obs.shape[0]))    
    
    return records

# %% [markdown]
# ### Data assimilation

# %%
#Load observed data
obs = np.load('data_obs.npy')

#Define Initial state & params
dt = 0.05
Xa = np.zeros(len(obs))
Pa = 25*np.matrix(np.identity(len(obs)))
C = np.zeros(len(obs), len(obs))
H = np.matrix(np.identity(len(obs)))
R =  np.matrix(np.identity(len(obs)))

# Assimilation
records = Kalman_filter(data, X0, P0, C, H, R ,dt, model=None)
